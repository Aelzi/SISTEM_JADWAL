# %% [markdown]
# ## Contoh Code Python

# %%
# import random

# # Daftar murid dan jadwal kosong mereka
# murid_jadwal = {
#     'Budi': ['Senin', 'Rabu', 'Jumat'],
#     'Andi': ['Senin', 'Kamis'],
#     'Citra': ['Selasa', 'Kamis'],
#     'Dian': ['Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat'],
#     'Anton': ['Selasa', 'Rabu', 'Kamis', 'Jumat'],
#     'Bud': ['Senin', 'Rabu', 'Jumat'],
#     'Ani': ['Senin', 'Kamis'],
#     'Cia': ['Selasa', 'Kamis','Sabtu'],
#     'Dan': ['Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat'],
#     'ton': ['Selasa', 'Rabu', 'Kamis', 'Jumat','Sabtu'],
    
    
#     # Tambahkan murid dan jadwal kosong mereka di sini
# }

# # Inisialisasi jadwal piket
# jadwal_piket = {hari: [] for hari in set([hari for jadwal in murid_jadwal.values() for hari in jadwal])}

# # Fungsi untuk membagi jadwal piket
# def bagi_jadwal_piket(murid_jadwal, jadwal_piket):
#     # Menghitung berapa kali setiap murid mendapatkan jadwal piket
#     murid_count = {murid: 0 for murid in murid_jadwal}

#     for hari in jadwal_piket:
#         murid_acak = list(murid_jadwal.keys())
#         random.shuffle(murid_acak)

#         for murid in murid_acak:
#             jadwal_kosong = murid_jadwal[murid]
#             if murid_count[murid] < 2 and hari in jadwal_kosong and len(jadwal_piket[hari]) < 2:
#                 jadwal_piket[hari].append(murid)
#                 murid_count[murid] += 1

# # Memanggil fungsi untuk membagi jadwal piket
# bagi_jadwal_piket(murid_jadwal, jadwal_piket)

# # Menampilkan jadwal piket
# for hari, murid_piket in jadwal_piket.items():
#     print(f'{hari}: {", ".join(murid_piket)}')

# %%
import pandas as pd

df= pd.read_csv('jadwal_kosong.csv')
df
# Out:
#     nama    hari
# 0    ABD  Selasa
# 1    ABD   Kamis
# 2    AWP    Rabu
# 3    AWP   Senin
# 4    AWP   Sabtu
# ..   ...     ...
# 375  JHS   Kamis
# 376  JHS  Selasa
# 377  ZAQ   Sabtu
# 378  ZAQ   Jumat
# 379  ZAQ  Selasa
#
# [380 rows x 2 columns]

# %% [markdown]
# ## Jadwal **terbagi rata**, tapi masi terdapat asisten yang **tidak dapat jadwal**

# %%
import csv
import random
import pandas as pd
from collections import defaultdict

# Membaca data dari file CSV
murid_jadwal = defaultdict(list)
file_path = 'jadwal_kosong.csv'

# Membaca file CSV dengan pandas
df = pd.read_csv(file_path)

# Membaca data dari DataFrame
for index, row in df.iterrows():
    nama, hari = row['nama'], row['hari']
    murid_jadwal[nama].append(hari)

# Inisialisasi jadwal piket
hari_piket = list(set([hari for jadwal in murid_jadwal.values() for hari in jadwal]))
jadwal_piket = {hari: [] for hari in hari_piket}

# Fungsi untuk membagi jadwal piket
def bagi_jadwal_piket(murid_jadwal, jadwal_piket):
    # Menghitung berapa kali setiap murid mendapatkan jadwal piket
    murid_count = {murid: 0 for murid in murid_jadwal}

    # Menghitung berapa kali setiap hari sudah mendapatkan siswa piket
    hari_count = {hari: 0 for hari in hari_piket}

    for hari in hari_piket:
        murid_acak = list(murid_jadwal.keys())
        random.shuffle(murid_acak)

        for murid in murid_acak:
            jadwal_kosong = murid_jadwal[murid]
            if murid_count[murid] < 2 and hari in jadwal_kosong and hari_count[hari] < len(murid_jadwal) / len(hari_piket):
                jadwal_piket[hari].append(murid)
                murid_count[murid] += 1
                hari_count[hari] += 1
            if all(murid_count[murid] == 2 for murid in murid_count) and all(hari_count[hari] == len(murid_jadwal) / len(hari_piket) for hari in hari_count):
                break

        # Memastikan setiap murid mendapatkan jadwal piket
        for murid in murid_jadwal:
            if murid not in murid_count:
                for hari in hari_piket:
                    if hari in murid_jadwal[murid] and hari_count[hari] < len(murid_jadwal) / len(hari_piket):
                        jadwal_piket[hari].append(murid)
                        murid_count[murid] += 1
                        hari_count[hari] += 1
                        break

# Memanggil fungsi untuk membagi jadwal piket
bagi_jadwal_piket(murid_jadwal, jadwal_piket)

# Menampilkan jadwal piket
for hari, murid_piket in jadwal_piket.items():
    print(f'{hari}: {", ".join(murid_piket)}')

# Mengkonversi jadwal piket menjadi DataFrame
df_jadwal_piket = pd.DataFrame(jadwal_piket)

# Menyimpan DataFrame ke dalam file CSV
df_jadwal_piket.to_csv('jadwal_piket1.csv', index=False)

# Mencari nama siswa yang tidak mendapatkan jadwal piket
nama_murid = set(murid_jadwal.keys())
nama_murid_terjadwal = set([murid for jadwal in jadwal_piket.values() for murid in jadwal])
nama_murid_tidak_terjadwal = nama_murid - nama_murid_terjadwal

# Menampilkan nama siswa yang tidak mendapatkan jadwal piket
if len(nama_murid_tidak_terjadwal) > 0:
    print(f'Siswa tidak mendapatkan jadwal piket: {", ".join(nama_murid_tidak_terjadwal)}')
else:
    print('Semua siswa mendapatkan jadwal piket')
# Out:
# Senin: DHY, FAZ, RAP, XCX, SOH, AWR, WGG, ALV, NOA, THI, ARC, DNR, MZY, DPR, OIL, JFT
# Kamis: FLL, NAB, VAN, NNY, IKI, CEN, BHL, DEY, AZA, AAA, NST, REZ, DNR, LIP, TIP, VIN
# Rabu: BIL, EZI, REN, OIL, ARF, NFB, RHN, NNY, GUS, SOH, AWR, VIN, CLA, MAI, BRI, LEX
# Sabtu: FAZ, BIL, GUS, JHS, MYC, VAN, DHY, OTU, RHN, PER, EZI, MZY, WAM, BHL, HAN, AMG
# Jumat: CEN, AKA, AAA, JIN, TAL, RIN, FAN, TNT, HAN, LIM, RIZ, ALV, ALL, TIP, RAM, CLA
# Selasa: RAP, QIA, OYA, WAM, GAA, RAM, JIN, JAY, NTR, FAN, REZ, ONE, THI, CYN, ARC, LIP
# Siswa tidak mendapatkan jadwal piket: RKH, FYN, DAR, MAS, ALF, RAR, ABD, VIS, TAN, AWP, EON, BIB, BDP, REY, IAN, EZL, WNA, LLY, MIQ, ZAQ, TGH, MNS, RIS, ALY, RAD

# %%
import pandas as pd
from IPython.display import display

# Membaca data dari file CSV
df_jadwal_piket = pd.read_csv('jadwal_piket.csv')

# Menghitung jumlah shift untuk setiap murid
shift_count = df_jadwal_piket.apply(pd.Series.value_counts).fillna(0).astype(int)

# Menampilkan hasilnya
display(shift_count)

df_jadwal_piket_compare = pd.DataFrame(shift_count)

# Menyimpan DataFrame ke dalam file CSV
df_jadwal_piket_compare.to_csv('jadwal_piket_compare.csv', index=True)
# Out:
#      Senin  Selasa  Rabu  Kamis  Jumat  Sabtu
# AAA      1       1     0      0      0      0
# ABD      0       1     0      1      0      0
# AKA      1       0     1      0      0      0
# ALF      1       0     1      0      0      0
# ALL      1       0     0      1      0      0
# ..     ...     ...   ...    ...    ...    ...
# WAM      1       1     0      0      0      0
# WGG      1       1     0      0      0      0
# WNA      1       1     0      0      0      0
# XCX      1       1     0      0      0      0
# ZAQ      0       1     0      0      1      0
#
# [91 rows x 6 columns]

# %% [markdown]
# ## SEMUA ASISTEN DAPAT JADWAL **TAPI TIDAK RATA**

# %%
import csv
import random
import pandas as pd
from collections import defaultdict

# Membaca data dari file CSV
murid_jadwal = defaultdict(list)
file_path = 'jadwal_kosong.csv'

# Membaca file CSV dengan pandas
df = pd.read_csv(file_path)

# Membaca data dari DataFrame
for index, row in df.iterrows():
    nama, hari = row['nama'], row['hari']
    murid_jadwal[nama].append(hari)

# Inisialisasi jadwal piket
hari_piket = ['Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat', 'Sabtu']
jadwal_piket = {hari: [] for hari in hari_piket}

# Fungsi untuk membagi jadwal piket
def bagi_jadwal_piket(murid_jadwal, jadwal_piket):
    # Menghitung berapa kali setiap murid mendapatkan jadwal piket
    murid_count = {murid: 0 for murid in murid_jadwal}
    print(murid_count)

    # Menghitung berapa kali setiap hari sudah mendapatkan siswa piket
    hari_count = {hari: 0 for hari in hari_piket}
    print(hari_count)

    # Jumlah siswa yang mendapatkan jadwal piket dalam seminggu
    jumlah_siswa_terjadwal = len(murid_jadwal) * 2  # 2 kali dalam seminggu

    for hari in hari_piket:
        murid_acak = list(murid_jadwal.keys())
        random.shuffle(murid_acak)

        for murid in murid_acak:
            jadwal_kosong = murid_jadwal[murid]
            if murid_count[murid] < 2 and hari in jadwal_kosong and hari_count[hari] < jumlah_siswa_terjadwal:
                jadwal_piket[hari].append(murid)
                murid_count[murid] += 1
                hari_count[hari] += 1
            if all(murid_count[murid] == 2 for murid in murid_count) and all(hari_count[hari] == jumlah_siswa_terjadwal for hari in hari_count):
                break

    # Memastikan setiap murid mendapatkan jadwal piket
    for murid in murid_jadwal:
        if murid not in murid_count:
            for hari in hari_piket:
                if hari in murid_jadwal[murid] and hari_count[hari] < jumlah_siswa_terjadwal:
                    jadwal_piket[hari].append(murid)
                    murid_count[murid] += 1
                    hari_count[hari] += 1
                    break

# Memanggil fungsi untuk membagi jadwal piket
bagi_jadwal_piket(murid_jadwal, jadwal_piket)

# Menampilkan jadwal piket
for hari, murid_piket in jadwal_piket.items():
    print(f'{hari}: {", ".join(murid_piket)}')

# Mengkonversi jadwal piket menjadi DataFrame
df_jadwal_piket = pd.DataFrame.from_dict(jadwal_piket, orient='index').T

# Menyimpan DataFrame ke dalam file CSV
df_jadwal_piket.to_csv('jadwal_piket2.csv', index=False)

# Mencari nama siswa yang tidak mendapatkan jadwal piket
nama_murid = set(murid_jadwal.keys())
nama_murid_terjadwal = set([murid for jadwal in jadwal_piket.values() for murid in jadwal])
nama_murid_tidak_terjadwal = nama_murid - nama_murid_terjadwal

# Menampilkan nama siswa yang tidak mendapatkan jadwal piket
if len(nama_murid_tidak_terjadwal) > 0:
    print(f'Siswa tidak mendapatkan jadwal piket: {", ".join(nama_murid_tidak_terjadwal)}')
else:
    print('Semua siswa mendapatkan jadwal piket')
# Out:
# {'ABD': 0, 'AWP': 0, 'GUS': 0, 'BRI': 0, 'AMG': 0, 'EZI': 0, 'LIP': 0, 'AKA': 0, 'ALY': 0, 'ALL': 0, 'ALV': 0, 'AZA': 0, 'AWR': 0, 'ARF': 0, 'WGG': 0, 'THI': 0, 'LLY': 0, 'BDP': 0, 'EZL': 0, 'DNR': 0, 'DAR': 0, 'DPR': 0, 'TAN': 0, 'DEY': 0, 'DHY': 0, 'MAS': 0, 'VAN': 0, 'FLL': 0, 'IAN': 0, 'RIN': 0, 'SOH': 0, 'GAA': 0, 'NNY': 0, 'OIL': 0, 'BIB': 0, 'JAY': 0, 'VIS': 0, 'JIN': 0, 'JFT': 0, 'TIP': 0, 'MNS': 0, 'MYC': 0, 'MZY': 0, 'EON': 0, 'FAN': 0, 'FYN': 0, 'MAI': 0, 'BHL': 0, 'ONE': 0, 'ALF': 0, 'AAA': 0, 'WAM': 0, 'PER': 0, 'MIQ': 0, 'NST': 0, 'CLA': 0, 'REN': 0, 'XCX': 0, 'HAN': 0, 'REZ': 0, 'RAM': 0, 'BIL': 0, 'NFB': 0, 'NTR': 0, 'RAR': 0, 'CYN': 0, 'OTU': 0, 'FAZ': 0, 'NAB': 0, 'RKH': 0, 'RHN': 0, 'RAD': 0, 'OYA': 0, 'NOA': 0, 'RAP': 0, 'REY': 0, 'IKI': 0, 'RIS': 0, 'RIZ': 0, 'ARC': 0, 'LIM': 0, 'QIA': 0, 'LEX': 0, 'TAL': 0, 'TGH': 0, 'CEN': 0, 'TNT': 0, 'VIN': 0, 'WNA': 0, 'JHS': 0, 'ZAQ': 0}
# {'Senin': 0, 'Selasa': 0, 'Rabu': 0, 'Kamis': 0, 'Jumat': 0, 'Sabtu': 0}
# Senin: MAS, JAY, WAM, RKH, THI, RAP, EZL, AWP, ALV, LLY, AKA, NST, NOA, SOH, DHY, ARF, JFT, AWR, ALL, PER, RAR, BIL, MIQ, WNA, DEY, EON, TAN, OIL, EZI, TAL, AZA, DPR, RIN, MNS, CLA, IAN, REN, BRI, ARC, BIB, GUS, NFB, REZ, NTR, DNR, QIA, XCX, WGG, ONE, VAN, RHN, FAZ, MYC, ALF, RIZ, AAA, LIP, MZY, DAR
# Selasa: HAN, VAN, ARC, NFB, OYA, XCX, TIP, FYN, JHS, THI, TAL, RIN, NTR, OTU, EON, QIA, BIL, AAA, MAI, FAZ, AZA, WGG, TGH, AMG, RKH, ONE, MYC, CYN, JFT, FLL, AWP, ZAQ, EZL, WNA, MZY, JAY, ABD, LLY, CLA, GAA, NAB, BHL, AWR, RAM, MIQ, RIS, JIN, DHY, REZ, RHN, MNS, VIN, CEN, IAN, RAP, OIL, PER, WAM, SOH, FAN, RAR, NOA, LIP, GUS, EZI
# Rabu: ARF, NNY, TAN, CEN, BRI, DNR, MAI, VIN, BDP, FYN, GAA, TIP, REN, IKI, OYA, RIS, JIN, ALF, BHL, AKA, HAN, ALY, DPR, BIB, RIZ, LEX, AMG, DAR, LIM
# Kamis: ABD, NST, NNY, OTU, NAB, FAN, TNT, RAD, MAS, FLL, ALY, JHS, BDP, ALL, CYN, VIS, ALV, IKI, DEY
# Jumat: TNT, ZAQ, LIM, REY, LEX, RAM, RAD
# Sabtu: REY, TGH, VIS
# Semua siswa mendapatkan jadwal piket

# %% [markdown]
# ### SEMUA DAPAT SHIFT, PEMBAGIAN MULAI RATA TAPI BELUM BAGUS

# %%
import csv
import random
import pandas as pd
from collections import defaultdict

# Membaca data dari file CSV
murid_jadwal = defaultdict(list)
file_path = 'jadwal_kosong.csv'

# Membaca file CSV dengan pandas
df = pd.read_csv(file_path)

# Membaca data dari DataFrame
for index, row in df.iterrows():
    nama, hari = row['nama'], row['hari']
    murid_jadwal[nama].append(hari)

# Inisialisasi jadwal piket
hari_piket = list(set([hari for jadwal in murid_jadwal.values() for hari in jadwal]))
jadwal_piket = {hari: [] for hari in hari_piket}

# Fungsi untuk membagi jadwal piket
def bagi_jadwal_piket(murid_jadwal, jadwal_piket):
    # Menghitung berapa kali setiap murid mendapatkan jadwal piket
    murid_count = {murid: 0 for murid in murid_jadwal}

    # Menghitung berapa kali setiap hari sudah mendapatkan siswa piket
    hari_count = {hari: 0 for hari in hari_piket}

    for hari in hari_piket:
        murid_acak = list(murid_jadwal.keys())
        random.shuffle(murid_acak)

        for murid in murid_acak:
            jadwal_kosong = murid_jadwal[murid]
            if murid_count[murid] < 2 and hari in jadwal_kosong and hari_count[hari] < len(murid_jadwal) / 2:
                jadwal_piket[hari].append(murid)
                murid_count[murid] += 1
                hari_count[hari] += 1

# Memanggil fungsi untuk membagi jadwal piket
bagi_jadwal_piket(murid_jadwal, jadwal_piket)

# Mengkonversi jadwal piket menjadi DataFrame
df_jadwal_piket = pd.DataFrame.from_dict(jadwal_piket, orient='index').T

# Menyimpan DataFrame ke dalam file CSV
df_jadwal_piket.to_csv('jadwal_piket3.csv', index=False)

# Menampilkan jadwal piket
for hari, murid_piket in jadwal_piket.items():
    print(f'{hari}: {", ".join(murid_piket)}')

# Mencari nama siswa yang tidak mendapatkan jadwal piket
nama_murid = set(murid_jadwal.keys())
nama_murid_terjadwal = set([murid for jadwal in jadwal_piket.values() for murid in jadwal])
nama_murid_tidak_terjadwal = nama_murid - nama_murid_terjadwal

# Menampilkan nama siswa yang tidak mendapatkan jadwal piket
if len(nama_murid_tidak_terjadwal) > 0:
    print(f'Siswa tidak mendapatkan jadwal piket: {", ".join(nama_murid_tidak_terjadwal)}')
else:
    print('Semua siswa mendapatkan jadwal piket')
# Out:
# Senin: NST, ARC, GUS, DAR, MIQ, MNS, EZI, ALF, FAZ, BIL, RHN, OIL, RAR, AWP, RIZ, JAY, ALL, REZ, BIB, AKA, NTR, VAN, DPR, ALV, EZL, AAA, RKH, XCX, WGG, TAN, NFB, RAP, AWR, CLA, LIP, PER, ONE, JFT, DNR, NOA, MAS, DEY, QIA, IAN, BRI, REN
# Kamis: AZA, LLY, NST, VIS, ARC, EZI, DEY, RKH, MZY, ABD, NAB, GAA, DPR, REZ, AMG, JFT, AWP, BHL, XCX, MNS, MIQ, IAN, DNR, MAS, AAA, RAR, FAN, NNY, BRI, NFB, CEN, EON, ONE, NOA, EZL, AWR, CLA, ALV, PER, JHS, JIN, RAD, TAL, LIP, FAZ, TNT
# Rabu: BIB, TIP, SOH, JIN, NNY, BDP, AKA, RIN, REN, NTR, RIZ, VAN, DHY, GUS, THI, RAP, MYC, LEX, WNA, RIS, GAA, BHL, OYA, AMG, TAL, IKI, VIN, DAR, LIM, EON, JAY, MAI, WGG, CEN, HAN, OIL, ARF, ALY, ALF, TAN, BIL, FYN, LLY, AZA, WAM, RHN
# Sabtu: ALY, IKI, THI, ZAQ, TNT, MZY, VIS, SOH, JHS, CYN, REY, OTU, OYA, TGH, FLL, WAM, TIP, MYC, DHY, HAN
# Jumat: RIN, RIS, ZAQ, VIN, MAI, RAM, LEX, ALL, FAN, LIM, QIA, REY, RAD
# Selasa: FYN, ABD, OTU, RAM, WNA, CYN, NAB, TGH, FLL
# Semua siswa mendapatkan jadwal piket

# %% [markdown]
# ### TERBAGI RATA TAPI MASI TERDAPAT SISWA YANG TIDAK DAPAT SHIFT

# %%
import csv
import random
import pandas as pd
from collections import defaultdict

# Membaca data dari file CSV
murid_jadwal = defaultdict(list)
file_path = 'jadwal_kosong.csv'

# Membaca file CSV dengan pandas
df = pd.read_csv(file_path)

# Membaca data dari DataFrame
for index, row in df.iterrows():
    nama, hari = row['nama'], row['hari']
    murid_jadwal[nama].append(hari)

# Inisialisasi jadwal piket
hari_piket = list(set([hari for jadwal in murid_jadwal.values() for hari in jadwal]))
jadwal_piket = {hari: [] for hari in hari_piket}

# Menyusun daftar siswa yang akan dijadwalkan berdasarkan urutan acak
murid_acak = list(murid_jadwal.keys())
random.shuffle(murid_acak)

# Membagi jadwal piket dengan lebih merata
for hari in hari_piket:
    siswa_piket = []
    
    for murid in murid_acak:
        if hari in murid_jadwal[murid] and len(siswa_piket) < len(murid_jadwal) / 2:
            siswa_piket.append(murid)
    
    jadwal_piket[hari] = siswa_piket
    
# Mengkonversi jadwal piket menjadi DataFrame
df_jadwal_piket = pd.DataFrame.from_dict(jadwal_piket, orient='index').T

# Menyimpan DataFrame ke dalam file CSV
df_jadwal_piket.to_csv('jadwal_piket4.csv', index=False)

# Menampilkan jadwal piket
for hari, murid_piket in jadwal_piket.items():
    print(f'{hari}: {", ".join(murid_piket)}')

# Mencari nama siswa yang tidak mendapatkan jadwal piket
nama_murid = set(murid_jadwal.keys())
nama_murid_terjadwal = set([murid for jadwal in jadwal_piket.values() for murid in jadwal])
nama_murid_tidak_terjadwal = nama_murid - nama_murid_terjadwal

# Menampilkan nama siswa yang tidak mendapatkan jadwal piket
if len(nama_murid_tidak_terjadwal) > 0:
    print(f'Siswa tidak mendapatkan jadwal piket: {", ".join(nama_murid_tidak_terjadwal)}')
else:
    print('Semua siswa mendapatkan jadwal piket')
# Out:
# Senin: CLA, AAA, NFB, DNR, THI, SOH, AWP, LLY, RIZ, VAN, EZI, RAP, IAN, MZY, FAZ, QIA, RKH, TAN, WAM, REZ, BIB, WNA, MNS, DPR, NST, MAS, EZL, RHN, ALF, XCX, ARF, GUS, REN, DEY, ARC, AKA, LIP, NOA, TAL, BRI, ALL, AWR, DHY, AZA, MYC, WGG
# Kamis: FAN, NNY, CLA, AAA, NFB, DNR, THI, SOH, BDP, AWP, LLY, VAN, EZI, TIP, VIS, CYN, IAN, MZY, FAZ, JIN, RKH, REZ, RAD, OTU, MNS, DPR, ABD, NST, MAS, GAA, EZL, RHN, ALY, JHS, XCX, GUS, AMG, FLL, DEY, NAB, ARC, BHL, AKA, LIP, IKI, NOA
# Rabu: NNY, CLA, AAA, NFB, DNR, THI, SOH, BDP, AWP, LLY, RIZ, VAN, EZI, TIP, RAP, IAN, FAZ, JIN, RKH, TAN, WAM, REZ, BIB, WNA, DPR, GAA, EZL, RHN, ALY, ALF, LEX, ARF, GUS, AMG, REN, ARC, BHL, AKA, FYN, IKI, TAL, BRI, RIS, AWR, DHY, CEN
# Sabtu: CLA, AAA, NFB, DNR, THI, SOH, AWP, LLY, RIZ, VAN, EZI, TIP, VIS, CYN, ZAQ, RAP, IAN, MZY, FAZ, JIN, RKH, TGH, WAM, REZ, OTU, MNS, DPR, NST, RHN, ALY, JHS, XCX, GUS, AMG, FLL, ARC, BHL, LIP, IKI, NOA, TAL, AWR, DHY, CEN, AZA, MYC
# Jumat: FAN, CLA, AAA, NFB, DNR, SOH, AWP, LLY, RIZ, VAN, EZI, TIP, ZAQ, RAP, IAN, MZY, FAZ, QIA, JIN, RKH, WAM, BIB, RAD, MNS, DPR, NST, MAS, GAA, RHN, JHS, LEX, GUS, AMG, ARC, AKA, LIP, RAM, IKI, TAL, BRI, ALL, RIS, AWR, CEN, AZA, MYC
# Selasa: FAN, CLA, AAA, NFB, THI, SOH, AWP, LLY, VAN, EZI, TIP, CYN, ZAQ, RAP, IAN, MZY, FAZ, QIA, JIN, RKH, TGH, WAM, REZ, OTU, WNA, MNS, ABD, GAA, EZL, RHN, JHS, XCX, GUS, AMG, FLL, NAB, ARC, BHL, FYN, LIP, RAM, NOA, TAL, RIS, AWR, DHY
# Siswa tidak mendapatkan jadwal piket: JFT, LIM, OIL, NTR, DAR, BIL, JAY, RAR, RIN, OYA, MAI, EON, REY, ONE, TNT, VIN, ALV, MIQ, HAN, PER

# %%
import csv
import random
import pandas as pd
from collections import defaultdict
from itertools import cycle

# Membaca data dari file CSV
murid_jadwal = defaultdict(list)
file_path = 'jadwal_kosong.csv'

# Membaca file CSV dengan pandas
df = pd.read_csv(file_path)

# Membaca data dari DataFrame
for index, row in df.iterrows():
    nama, hari = row['nama'], row['hari']
    murid_jadwal[nama].append(hari)

# Inisialisasi jadwal piket
hari_piket = list(set([hari for jadwal in murid_jadwal.values() for hari in jadwal]))

# Membuat daftar siswa yang akan dijadwalkan
murid_acak = list(murid_jadwal.keys())
random.shuffle(murid_acak)

# Menentukan urutan pengisian hari secara bergantian (Senin-Sabtu)
hari_order = cycle(hari_piket)

# Fungsi untuk mengecek apakah sebuah jadwal konflik atau tidak
def is_schedule_valid(schedule, student, day):
    # Cek apakah siswa sudah dijadwalkan lebih dari 2 kali dalam seminggu
    if schedule.count(student) >= 2:
        return False
    
    # Cek apakah hari tersebut sesuai dengan jadwal kosong siswa
    if day not in murid_jadwal[student]:
        return False
    
    return True

# Inisialisasi jadwal piket
jadwal_piket = {hari: [] for hari in hari_piket}

for day in hari_order:
    # Membuat salinan daftar siswa yang belum mendapatkan jadwal pada hari ini
    remaining_students = [murid for murid in murid_acak if is_schedule_valid(jadwal_piket[day], murid, day)]
    
    if remaining_students:
        # Pilih siswa secara acak dari yang tersisa
        selected_student = random.choice(remaining_students)
        jadwal_piket[day].append(selected_student)
    
    # Menghentikan pengulangan setelah semua siswa mendapatkan jadwal
    if all(len(jadwal_piket[hari]) >= 2 for hari in hari_piket):
        break

# Menampilkan jadwal piket
for hari, murid_piket in jadwal_piket.items():
    print(f'{hari}: {", ".join(murid_piket)}')

# Mencari nama siswa yang tidak mendapatkan jadwal piket
nama_murid = set(murid_jadwal.keys())
nama_murid_terjadwal = set([murid for jadwal in jadwal_piket.values() for murid in jadwal])
nama_murid_tidak_terjadwal = nama_murid - nama_murid_terjadwal

# Menampilkan nama siswa yang tidak mendapatkan jadwal piket
if len(nama_murid_tidak_terjadwal) > 0:
    print(f'Siswa tidak mendapatkan jadwal piket: {", ".join(nama_murid_tidak_terjadwal)}')
else:
    print('Semua siswa mendapatkan jadwal piket')
# Out:
# Senin: AWP, ALL
# Kamis: SOH, REZ
# Rabu: ARF, CLA
# Sabtu: THI, WAM
# Jumat: JHS, LIP
# Selasa: WNA, TAL
# Siswa tidak mendapatkan jadwal piket: OIL, FYN, QIA, NTR, NNY, DNR, DAR, FAN, TIP, NST, AMG, JAY, RAR, XCX, DHY, RIN, WGG, TAN, BHL, ARC, AZA, GAA, DEY, OTU, OYA, NFB, VAN, CYN, MAI, GUS, EON, BIB, BDP, REN, IAN, EZL, VIN, ALV, LEX, AAA, MIQ, RIZ, TGH, MZY, JIN, HAN, RAD, JFT, LIM, RKH, AWR, EZI, BIL, MAS, IKI, ALF, CEN, ABD, AKA, VIS, RAM, NOA, RAP, MYC, REY, ONE, TNT, NAB, LLY, FAZ, ZAQ, DPR, MNS, RHN, RIS, BRI, FLL, ALY, PER
